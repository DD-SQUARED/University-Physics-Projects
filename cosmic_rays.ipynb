# %% [markdown]
# <a href="https://colab.research.google.com/github/DD-SQUARED/University-Physics-Projects/blob/main/cosmic_rays.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Data
years = [1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000]
cr_intensity = [1.500804925174286, 1.199044367226923, 0.8115951812109165, 0.5366238575339167, 0.3669187832059091, 0.438790637392200, 0.4806194096609231, 0.6569328385565385,
                0.8536221188307856, 1.158862074425214, 1.316132629369286, 0.9459003757316429, 0.4815956729598889, 0.2628997633301667, 0.349714138832400, 0.6922570372359231, 1.069285397609786,
                1.231881924721429, 1.431104158983572, 1.550089464722857, 1.569463653332857, 1.339366218098571, 0.9934481852261429, 0.5087885773923001]

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(years, cr_intensity, label='CR Proton Intensity', color='blue', marker='o')
plt.xlabel('Year')
plt.ylabel('CR Proton Intensity')
plt.title('Cosmic Ray Proton Intensity vs. Year')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Magnetic Field Strength Data
magnetic_field = [5.92312643678161, 7.159176245210727, 7.662289272030651, 6.788706896551723, 8.01028735632184,
                  8.63852490421456, 8.114837164750958, 7.929243295019158, 6.022777777777777, 5.784157088122606,
                  6.117787356321842, 7.298055555555557, 8.11624521072797, 7.763486590038312, 8.974300766283525,
                  8.476513409961688, 6.769712643678161, 6.406934865900385, 5.806810344827586, 5.117231800766283,
                  5.431321839080461, 6.795890804597701, 6.82919540229885, 7.317231800766283]

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(years, magnetic_field, label='Magnetic Field Strength', color='red', marker='x')
plt.xlabel('Year')
plt.ylabel('Magnetic Field Strength (nT)')
plt.title('Magnetic Field Strength vs. Year')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Average Magnetic Field
avg_B = sum(magnetic_field) / len(magnetic_field)
print(f"Average Magnetic Field Strength: {avg_B:.2f} nT")
# Out:
# Average Magnetic Field Strength: 7.05 nT

# %%
import numpy as np

# Magnetic field data
magnetic_field = [5.92312643678161, 7.159176245210727, 7.662289272030651, 6.788706896551723,
                  8.01028735632184, 8.63852490421456, 8.114837164750958, 7.929243295019158,
                  6.022777777777777, 5.784157088122606, 6.117787356321842, 7.298055555555557,
                  8.11624521072797, 7.763486590038312, 8.974300766283525, 8.476513409961688,
                  6.769712643678161, 6.406934865900385, 5.806810344827586, 5.117231800766283,
                  5.431321839080461, 6.795890804597701, 6.82919540229885, 7.317231800766283]

# Calculate average magnetic field
avg_B = np.mean(magnetic_field)
print(f"Average Magnetic Field Strength: {avg_B:.2f} nT")
# Out:
# Average Magnetic Field Strength: 7.05 nT

# %%
# CR proton intensity data
cr_intensity = [1.500804925174286, 1.199044367226923, 0.8115951812109165, 0.5366238575339167,
                0.3669187832059091, 0.438790637392200, 0.4806194096609231, 0.6569328385565385,
                0.8536221188307856, 1.158862074425214, 1.316132629369286, 0.9459003757316429,
                0.4815956729598889, 0.2628997633301667, 0.349714138832400, 0.6922570372359231,
                1.069285397609786, 1.231881924721429, 1.431104158983572, 1.550089464722857,
                1.569463653332857, 1.339366218098571, 0.9934481852261429, 0.5087885773923001]

# Voyager observations at 85 AU (P = 1.28 GV)
P = 1.28  # GV
j_b_85_au = 2.936
print(f"j_b(85 AU): {j_b_85_au:.2e}")

# Calculate M for each year
M_values = [-np.log(j / j_b_85_au) for j in cr_intensity]

# Print the modulation parameter M for each year
for year, M in zip(range(1977, 2001), M_values):
    print(f"Year: {year}, M: {M:.2f}")
import matplotlib.pyplot as plt

# Year data
years = [1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990,
         1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000]

# Plotting M vs Year
plt.figure(figsize=(10, 6))
plt.plot(years, M_values, label='Modulation Parameter M', color='green', marker='s')
plt.xlabel('Year')
plt.ylabel('Modulation Parameter M')
plt.title('Modulation Parameter vs. Year')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# j_b(85 AU): 2.94e+00
# Year: 1977, M: 0.67
# Year: 1978, M: 0.90
# Year: 1979, M: 1.29
# Year: 1980, M: 1.70
# Year: 1981, M: 2.08
# Year: 1982, M: 1.90
# Year: 1983, M: 1.81
# Year: 1984, M: 1.50
# Year: 1985, M: 1.24
# Year: 1986, M: 0.93
# Year: 1987, M: 0.80
# Year: 1988, M: 1.13
# Year: 1989, M: 1.81
# Year: 1990, M: 2.41
# Year: 1991, M: 2.13
# Year: 1992, M: 1.44
# Year: 1993, M: 1.01
# Year: 1994, M: 0.87
# Year: 1995, M: 0.72
# Year: 1996, M: 0.64
# Year: 1997, M: 0.63
# Year: 1998, M: 0.78
# Year: 1999, M: 1.08
# Year: 2000, M: 1.75

# %%
import matplotlib.pyplot as plt

# Magnetic Field Strength Data
gamma = [-4.09E-01, 2.43E+01, 8.76E+00, -2.63E+01, 9.45E+00, 5.49E+00, 7.59E+00,
         7.48E+00, -4.35E+00, -2.01E+00, -1.75E+00, 1.73E+01, 7.58E+00, 1.41E+01,
         5.09E+00, 4.55E+00, -1.18E+01, -3.46E+00, -7.37E-01, -7.94E-02, -3.72E-02,
         -6.03E+00, -1.71E+01, 2.80E+01]

# Define the years array (you should provide the actual years)
years = [1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987,
         1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998,
         1999, 2000]

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(years, gamma, label='Gamma', color='green', marker='x')
plt.xlabel('Year')
plt.ylabel('Gamma')
plt.title('Gamma vs. Year')
plt.grid(True)
plt.legend()
plt.show()
